# %% [markdown]
# # ⚡ *`Carga de archivos en Colab`* ⚡
#
# ## Cómo trabajar con Google Colaboratory subiendo archivos
#     Ver notebook de Pandas para mayor información

# %% [markdown]
# ### Leyendo desde archivos, sin necesidad de montar Colab y los permisos
#
#     > La carga de los archivos es temporal

# %%
import pandas as pd

df_titanic = pd.read_csv("titanic.csv")
df_sales = pd.read_csv("sales_train.csv")

# %%
df_titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df_sales.head(2)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013             0.0     59.0  22154.0       999.0           1.0
# 1  03.01.2013             0.0     25.0   2552.0       899.0           1.0

# %% [markdown]
# ### Conectando Drive con Colab

# %%
# Conectar Drive a Colab
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Leyendo desde sample_data, requiere montar el Drive

# %%
titanic_sample_data = pd.read_csv("/content/sample_data/titanic.csv")
titanic_sample_data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
sales_train_sample_data = pd.read_csv("/content/sample_data/sales_train.csv")
sales_train_sample_data.head(2)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2552       899.0           1.0

# %% [markdown]
# ### Leyendo desde la ruta a una carpeta, requiere montar el Drive
#
# - > "/content/drive/My Drive/Datapath Ingeniería de Datos/Módulo 5 Análisis de Datos con Python/Data/titanic.csv"
# - > "/content/drive/My Drive/Datapath Ingeniería de Datos/Módulo 5 Análisis de Datos con Python/Data/sales_train.csv"

# %%
titanic = pd.read_csv('/content/drive/My Drive/Datapath Ingeniería de Datos/Módulo 5 Análisis de Datos con Python/Data/titanic.csv')
sales = pd.read_csv('/content/drive/My Drive/Datapath Ingeniería de Datos/Módulo 5 Análisis de Datos con Python/Data/sales_train.csv')

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
sales.head(3)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2552       899.0           1.0
# 2  05.01.2013               0       25     2552       899.0          -1.0

# %% [markdown]
# ### **Fin Notebook**
